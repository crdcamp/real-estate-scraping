# %% [markdown]
# # Start by Retrieving the Most Recent Data

# %%
import requests
from datetime import datetime

def get_database_ppis():
    """Retrieve all PPIs from the database (layer 12) for comparison"""
    url = "https://gis.summitcountyco.gov/arcgis/rest/services/ParcelQueryTool/SummitMap1_Pro321/MapServer/12/query"
    
    all_features = []
    batch_size = 1000
    offset = 0
    params = {
        "where": "1=1",
        "outFields": "*",  # Get all fields for matching features
        "f": "json",
        "returnGeometry": "false",
        "outSR": "102654",
        "resultRecordCount": batch_size
    }
    
    print("Loading database PPIs for comparison...")
    
    try:
        while True:
            params["resultOffset"] = offset
            
            response = requests.get(url, params=params)
            response.raise_for_status()
            
            data = response.json()
            
            if "features" not in data or not data["features"]:
                break
                
            all_features.extend(data["features"])
            
            if len(data["features"]) < batch_size:
                break
                
            offset += batch_size
        
        # Create a dictionary mapping PPI to feature data
        ppi_to_feature = {}
        for feature in all_features:
            ppi = feature.get("attributes", {}).get("PPI")
            if ppi is not None:
                ppi_to_feature[ppi] = feature
        
        print(f"Loaded {len(ppi_to_feature)} unique PPIs from database")
        return ppi_to_feature
        
    except requests.exceptions.RequestException as e:
        print(f"Error querying the database: {e}")
        return {}

def main():
    num_results = 5
    
    # Get database PPIs for comparison
    database_ppis = get_database_ppis()
    
    if not database_ppis:
        print("Failed to load database PPIs. Exiting.")
        return
    
    # Query URL with adjustable result count
    query_url = f"https://gis.summitcountyco.gov/arcgis/rest/services/ParcelQueryTool/SummitMap1_Pro321/MapServer/19/query?where=SOURCE=1&orderByFields=MODDATE%20DESC&resultRecordCount={num_results}&outFields=*&returnGeometry=false&f=json"
    
    # Send the request
    response = requests.get(query_url)
    if response.status_code == 200:
        data = response.json()
        features = data.get("features", [])
        
        matching_count = 0
        
        for i, feature in enumerate(features, 1):
            attributes = feature.get("attributes", {})
            ppi = attributes.get("PPI")
            mod_date = attributes.get("MODDATE")
            
            # Convert MODDATE (Unix timestamp in milliseconds) to readable date
            if mod_date:
                mod_date_readable = datetime.fromtimestamp(mod_date / 1000).strftime("%Y-%m-%d %H:%M:%S")
            else:
                mod_date_readable = "N/A"
            
            # Only print if PPI exists in database
            if ppi in database_ppis:
                matching_count += 1
                database_feature = database_ppis[ppi]
                database_attributes = database_feature.get("attributes", {})
                
                if matching_count == 1:  # Print header only when first match is found
                    print(f"\nMatching PPIs from Most Recently Modified Parcels:")
                
                print(f"\n--- Match #{matching_count} - PPI: {ppi} ---")
                print(f"Modified Date: {mod_date_readable}")
                
                # Print all attributes from the query result (layer 19)
                print("\nMODTYPE ATTRIBUTES:")
                for key, value in attributes.items():
                    print(f"  {key}: {value}")
                
                # Print all attributes from the database result (layer 12)
                print("\nSCHEDULE ID ATTRIBUTES:")
                for key, value in database_attributes.items():
                    print(f"  {key}: {value}")
                
                print("-" * 50)
        
        # Summary
        if matching_count > 0:
            print(f"\nSUMMARY:")
            print(f"Total queried parcels: {len(features)}")
            print(f"Matching PPIs found in database: {matching_count}")
            print(f"Match percentage: {(matching_count/len(features)*100):.1f}%")
        else:
            print(f"\nNo matching PPIs found in database out of {len(features)} queried parcels.")
        
    else:
        print(f"Error: Unable to fetch data. Status code: {response.status_code}")

if __name__ == "__main__":
    main()
# Out:
# Loading database PPIs for comparison...
# Loaded 21031 unique PPIs from database
#
# Matching PPIs from Most Recently Modified Parcels:
#
# --- Match #1 - PPI: 1697-3440-00-014 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   OBJECTID: 367
#   sde.GIS.Parcel.AREA: 247939.78546832374
#   PERIMETER: 7126.66105626297
#   PPI: 1697-3440-00-014
#   SOURCE: 1
#   MODDATE: 1748304000000
#   MODTYPE: 4
#   METHOD: 1
#   OPERATOR: CM
#   X_COORD: 2795535.55688181
#   Y_COORD: 1730561.7727167478
#   PPIT:
#   PPIS:
#   PPIQS:
#   PPISS:
#   PPIB:
#   PPIL:
#   TicketID: None
#   Latitude: 39.83695322
#   Longitude: -106.22807105
#   Shape.area: 247939.785468338
#   Shape.len: 7126.661056262793
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 353
#   OBJECTID: 19851
#   PPI: 1697-3440-00-014
#   Schedule: 4008327
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 9000
#   SubName: METES & BOUNDS (ALL)
#   Filing: 0
#   Phase: 0
#   PrimaryID:
#   SecondID:
#   ShortDesc: TR 2-79 Sec 34 Qtr 4 Acres 82.110 AKA TR
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   Abstract1: 9122
#   Abstract2: 0
#   Abstract3: 0
#   Abstract4: 0
#   Abstracts: 9122
#   TotAssLand: 0.0
#   TotAssImp: 0.0
#   TotTaxLand: 0.0
#   TotTaxImp: 0.0
#   TotTaxVal: 0.0
#   TotAssVal: 0.0
#   TaxYear: 2025
#   TaxArea: 17
#   TaxMills: 52.601
#   OwnerAdd1: 6060 BROADWAY
#   OwnerAdd2:
#   OwnerCity: DENVER
#   OwnerState: CO
#   PostCode: 80216
#   FullAdd: 6060 BROADWAY|DENVER, CO 80216
#   TotAcres: 82.11
#   TotSqFt: 3576711
#   BODensity: 0
#   ActBODen: 0
#   PotBOsqft: 0
#   ActBOsqft: 0
#   SingFamEq: 0
#   SiteAccess: 5
#   SiteTopo: 3
#   SiteView: 5
#   SiteCover: 2
#   SiteSewer: 1
#   SiteWater: 1
#   SiteUtil: 2
#   MiscChar: Borders Open Space:Forest Service, Hydrology:Riverfront
#   MiscCharID: 4, 22
#   NumStruct: 0
#   ImpType:
#   ArchCode:
#   ArchStyle:
#   NumUnits: 0
#   YearBuilt: 0
#   AdjYear: 0
#   ImpGrade:
#   ImpCond:
#   ConstClass:
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: 0
#   SqeFtLiving: 0
#   Unfinished: 0
#   BsmtType:
#   GarageType:
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 0
#   NumBedRms: 0
#   NumLofts: 0
#   NumKitch: 0
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
#   CommUse1:
#   CommUse2:
#   CommUse3:
#   CommUses: None
#   ExtCond:
#   Shape.STArea(): 4322071.466039252
#   Shape.STLength(): 28937.076425209234
# --------------------------------------------------
#
# --- Match #2 - PPI: 1951-0610-00-016 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   OBJECTID: 714
#   sde.GIS.Parcel.AREA: 47493.4978379938
#   PERIMETER: 912.3502390552982
#   PPI: 1951-0610-00-016
#   SOURCE: 1
#   MODDATE: 1748304000000
#   MODTYPE: 4
#   METHOD: 1
#   OPERATOR: CM
#   X_COORD: 2812582.755083284
#   Y_COORD: 1693192.0701738305
#   PPIT: 1951
#   PPIS: 06
#   PPIQS: 1
#   PPISS: 0
#   PPIB: 00
#   PPIL: 016
#   TicketID: 14067
#   Latitude: 39.73472892
#   Longitude: -106.16639434
#   Shape.area: 50608.57925562416
#   Shape.len: 933.9493528072596
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 618
#   OBJECTID: 18316
#   PPI: 1951-0610-00-016
#   Schedule: 3000334
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 920
#   SubName: MEADOWBROOK ACRES SUB
#   Filing: 0
#   Phase: 0
#   PrimaryID:
#   SecondID: Tract A4
#   ShortDesc: TRACT A4 MEADOWBROOK ACRES SUB
#   AddressID: 48953
#   StreetID: 1057
#   SitusAdd: 2033 Meadowbrook LN (CR 1378)
#   HouseNum: 2033
#   FullStreet: Meadowbrook LN (CR 1378)
#   StreetName: Meadowbrook
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   Abstract1: 1112
#   Abstract2: 1212
#   Abstract3: 0
#   Abstract4: 0
#   Abstracts: 1112;1212
#   TotAssLand: 5244.0
#   TotAssImp: 27706.0
#   TotTaxLand: 83900.0
#   TotTaxImp: 443300.0
#   TotTaxVal: 527200.0
#   TotAssVal: 32950.0
#   TaxYear: 2025
#   TaxArea: 30
#   TaxMills: 38.813
#   OwnerAdd1: 110 MOSS WAY
#   OwnerAdd2:
#   OwnerCity: SILVERTHORNE
#   OwnerState: CO
#   PostCode: 80498-7534
#   FullAdd: 110 MOSS WAY|SILVERTHORNE, CO 80498-7534
#   TotAcres: 1.098
#   TotSqFt: 47828
#   BODensity: 1
#   ActBODen: 1
#   PotBOsqft: 0
#   ActBOsqft: 0
#   SingFamEq: 1
#   SiteAccess: 2
#   SiteTopo: 2
#   SiteView: 3
#   SiteCover: 4
#   SiteSewer: 1
#   SiteWater: 1
#   SiteUtil: 5
#   MiscChar: None
#   MiscCharID:
#   NumStruct: 1
#   ImpType: SFR Improvement
#   ArchCode: 10
#   ArchStyle: Two Story
#   NumUnits: 1
#   YearBuilt: 1964
#   AdjYear: 1976
#   ImpGrade: Fair
#   ImpCond: Fair
#   ConstClass: Unknown
#   ExtWallMat: Wood Siding
#   ExtWallHgt: -1
#   HeatType: None
#   SquareFeet: 1128
#   SqeFtLiving: 1128
#   Unfinished: 0
#   BsmtType: None
#   GarageType: None
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 4
#   NumBedRms: 2
#   NumLofts: 0
#   NumKitch: 1
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos: Standalone
#   CommUse1:
#   CommUse2:
#   CommUse3:
#   CommUses: None
#   ExtCond:
#   Shape.STArea(): 50608.59108260322
#   Shape.STLength(): 933.9495443759463
# --------------------------------------------------
#
# --- Match #3 - PPI: 1951-0610-00-011 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   OBJECTID: 728
#   sde.GIS.Parcel.AREA: 3114.7617110307706
#   PERIMETER: 382.93131412708334
#   PPI: 1951-0610-00-011
#   SOURCE: 1
#   MODDATE: 1748304000000
#   MODTYPE: 0
#   METHOD: 1
#   OPERATOR: CM
#   X_COORD: 2812768.3793719504
#   Y_COORD: 1692904.211689722
#   PPIT: 1951
#   PPIS: 06
#   PPIQS: 0
#   PPISS: 0
#   PPIB: 00
#   PPIL: 999
#   TicketID: None
#   Latitude: 39.73394244
#   Longitude: -106.16572685
#   Shape.area: 3114.7617110279357
#   Shape.len: 382.93131412634636
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 613
#   OBJECTID: 19217
#   PPI: 1951-0610-00-011
#   Schedule: 3001794
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 9000
#   SubName: METES & BOUNDS (ALL)
#   Filing: 0
#   Phase: 0
#   PrimaryID:
#   SecondID:
#   ShortDesc: TR 4-78 Sec 06 Qtr 1 Acres 4.0000
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   Abstract1: 521
#   Abstract2: 0
#   Abstract3: 0
#   Abstract4: 0
#   Abstracts: 521
#   TotAssLand: 60831.0
#   TotAssImp: 0.0
#   TotTaxLand: 225300.0
#   TotTaxImp: 0.0
#   TotTaxVal: 225300.0
#   TotAssVal: 60831.0
#   TaxYear: 2025
#   TaxArea: 30
#   TaxMills: 38.813
#   OwnerAdd1: C/O ROBERT MC DOUGAL
#   OwnerAdd2: 600 JOSEPHINE ST
#   OwnerCity: DENVER
#   OwnerState: CO
#   PostCode: 80206-3723
#   FullAdd: C/O ROBERT MC DOUGAL|600 JOSEPHINE ST|DENVER, CO 80206-3723
#   TotAcres: 4.0
#   TotSqFt: 174240
#   BODensity: 1
#   ActBODen: 0
#   PotBOsqft: 0
#   ActBOsqft: 0
#   SingFamEq: 1
#   SiteAccess: 13
#   SiteTopo: 1
#   SiteView: 3
#   SiteCover: 5
#   SiteSewer: 1
#   SiteWater: 1
#   SiteUtil: 1
#   MiscChar: Borders Open Space:Forest Service
#   MiscCharID: 4
#   NumStruct: 0
#   ImpType:
#   ArchCode:
#   ArchStyle:
#   NumUnits: 0
#   YearBuilt: 0
#   AdjYear: 0
#   ImpGrade:
#   ImpCond:
#   ConstClass:
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: 0
#   SqeFtLiving: 0
#   Unfinished: 0
#   BsmtType:
#   GarageType:
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 0
#   NumBedRms: 0
#   NumLofts: 0
#   NumKitch: 0
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
#   CommUse1:
#   CommUse2:
#   CommUse3:
#   CommUses: None
#   ExtCond:
#   Shape.STArea(): 404658.9005375471
#   Shape.STLength(): 5800.3173024632415
# --------------------------------------------------
#
# --- Match #4 - PPI: 1951-0630-00-008 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   OBJECTID: 731
#   sde.GIS.Parcel.AREA: 28566.35313545222
#   PERIMETER: 1000.3120100867637
#   PPI: 1951-0630-00-008
#   SOURCE: 1
#   MODDATE: 1748304000000
#   MODTYPE: 4
#   METHOD: 1
#   OPERATOR: CM
#   X_COORD: 2811749.1072277343
#   Y_COORD: 1692063.312811482
#   PPIT: 1951
#   PPIS: 06
#   PPIQS: 3
#   PPISS: 0
#   PPIB: 00
#   PPIL: 008
#   TicketID: None
#   Latitude: 39.73161348
#   Longitude: -106.16932884
#   Shape.area: 43157.870053334744
#   Shape.len: 880.2807262779154
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 637
#   OBJECTID: 18266
#   PPI: 1951-0630-00-008
#   Schedule: 3000256
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 920
#   SubName: MEADOWBROOK ACRES SUB
#   Filing: 0
#   Phase: 0
#   PrimaryID:
#   SecondID: Tract J
#   ShortDesc: TRACT J MEADOWBROOK ACRES SUB
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   Abstract1: 521
#   Abstract2: 0
#   Abstract3: 0
#   Abstract4: 0
#   Abstracts: 521
#   TotAssLand: 34884.0
#   TotAssImp: 0.0
#   TotTaxLand: 129200.0
#   TotTaxImp: 0.0
#   TotTaxVal: 129200.0
#   TotAssVal: 34884.0
#   TaxYear: 2025
#   TaxArea: 30
#   TaxMills: 38.813
#   OwnerAdd1: C/O W D HABISH JR
#   OwnerAdd2: PO BOX 294
#   OwnerCity: WESTMINSTER
#   OwnerState: CO
#   PostCode: 80030-0294
#   FullAdd: C/O W D HABISH JR|PO BOX 294|WESTMINSTER, CO 80030-0294
#   TotAcres: 1.0
#   TotSqFt: 43560
#   BODensity: 1
#   ActBODen: 0
#   PotBOsqft: 0
#   ActBOsqft: 0
#   SingFamEq: 1
#   SiteAccess: 2
#   SiteTopo: 2
#   SiteView: 3
#   SiteCover: 3
#   SiteSewer: 1
#   SiteWater: 1
#   SiteUtil: 1
#   MiscChar: None
#   MiscCharID:
#   NumStruct: 0
#   ImpType:
#   ArchCode:
#   ArchStyle:
#   NumUnits: 0
#   YearBuilt: 0
#   AdjYear: 0
#   ImpGrade:
#   ImpCond:
#   ConstClass:
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: 0
#   SqeFtLiving: 0
#   Unfinished: 0
#   BsmtType:
#   GarageType:
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 0
#   NumBedRms: 0
#   NumLofts: 0
#   NumKitch: 0
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
#   CommUse1:
#   CommUse2:
#   CommUse3:
#   CommUses: None
#   ExtCond:
#   Shape.STArea(): 43157.861842740815
#   Shape.STLength(): 880.2807682319658
# --------------------------------------------------
#
# --- Match #5 - PPI: 2097-3540-00-078 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   OBJECTID: 11034
#   sde.GIS.Parcel.AREA: 13277.968813589003
#   PERIMETER: 697.5742225451835
#   PPI: 2097-3540-00-078
#   SOURCE: 1
#   MODDATE: 1748304000000
#   MODTYPE: 4
#   METHOD: 1
#   OPERATOR: CM
#   X_COORD: 2834073.754498416
#   Y_COORD: 1633364.5462021572
#   PPIT:
#   PPIS:
#   PPIQS:
#   PPISS:
#   PPIB:
#   PPIL:
#   TicketID: None
#   Latitude: 39.57089539
#   Longitude: -106.0886034
#   Shape.area: 13277.968813613552
#   Shape.len: 697.5742225448407
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 20592
#   OBJECTID: 37152
#   PPI: 2097-3540-00-078
#   Schedule: 6518943
#   EcoCode: 2
#   EcoDesc: Frisco
#   NhoodCode: 23000
#   NhoodDescr: Frisco Town
#   SubCode: 9000
#   SubName: METES & BOUNDS (ALL)
#   Filing: 0
#   Phase: 0
#   PrimaryID:
#   SecondID:
#   ShortDesc: Improvement Only TR 5-78 Sec 35 Qtr 4 Sq
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   Abstract1: 0
#   Abstract2: 0
#   Abstract3: 0
#   Abstract4: 0
#   Abstracts: None
#   TotAssLand: 0.0
#   TotAssImp: 0.0
#   TotTaxLand: 0.0
#   TotTaxImp: 0.0
#   TotTaxVal: 0.0
#   TotAssVal: 0.0
#   TaxYear: 2025
#   TaxArea: 25
#   TaxMills: 51.723
#   OwnerAdd1: PO BOX 68
#   OwnerAdd2:
#   OwnerCity: BRECKENRIDGE
#   OwnerState: CO
#   PostCode: 80424-0068
#   FullAdd: PO BOX 68|BRECKENRIDGE, CO 80424-0068
#   TotAcres: 0.0
#   TotSqFt: 0
#   BODensity: 1
#   ActBODen: 1
#   PotBOsqft: 0
#   ActBOsqft: 0
#   SingFamEq: 1
#   SiteAccess: 5
#   SiteTopo: 3
#   SiteView: 4
#   SiteCover: 4
#   SiteSewer: 3
#   SiteWater: 3
#   SiteUtil: 4
#   MiscChar: Restrictions:Conservation Easement
#   MiscCharID: 32
#   NumStruct: 1
#   ImpType:
#   ArchCode:
#   ArchStyle:
#   NumUnits: -1
#   YearBuilt: -1
#   AdjYear: -1
#   ImpGrade:
#   ImpCond:
#   ConstClass:
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: -1
#   SqeFtLiving: -1
#   Unfinished: -1
#   BsmtType:
#   GarageType:
#   NumOfCars: -1
#   GarSqFt: -1
#   NumOfRms: -1
#   NumBedRms: -1
#   NumLofts: -1
#   NumKitch: -1
#   MasterBath: -1
#   FullBath: -1
#   TqtrBaths: -1
#   HalfBaths: -1
#   QtrBaths: -1
#   TotBath: -1.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
#   CommUse1:
#   CommUse2:
#   CommUse3:
#   CommUses: None
#   ExtCond:
#   Shape.STArea(): 2404494.717550508
#   Shape.STLength(): 9767.848330318711
# --------------------------------------------------
#
# SUMMARY:
# Total queried parcels: 5
# Matching PPIs found in database: 5
# Match percentage: 100.0%

# %% [markdown]
# # Adjusting Query to Only Pring Relevant Results
#
# ## MODTYPE Relevant Attributes
#
# sde.GIS.Parcel.AREA
# PERIMETER
# OBJECTID
# PPI
# SOURCE
# MODDATE
# MODTYPE
#
# ## Schedule ID Relevant Attributes
#
# OBJECTID_1
# OBJECTID
# PPI
# Schedule
# EcoCode
# EcoDesc
# NhoodCode
# NhoodDescr
# SubCode
# SubName
# SecondID
# ShortDesc
# AddressID
# StreetID
# SitusAdd
# HouseNum
# FullStreet
# StreetName
# TownCode
# TownName
# OwnerAdd1
# OwnerAdd2
# OwnerCity
# OwnerState
# PostCode
# FullAdd
# TotAcres
# TotSqFt
# YearBuilt
# ExtWallMat
# ExtWallHgt
# HeatType
# SquareFeet
# SqeFtLiving
# Unfinished
# BsmtType
# GarageType
# NumOfCars
# GarSqFt
# NumOfRms
# NumBedRms
# NumLofts
# NumKitch
# MasterBath
# FullBath
# TqtrBaths
# HalfBaths
# QtrBaths
# TotBath
# MobHtitle
# FloorLevel
# ImpPos

# %%
import requests
from datetime import datetime

def get_database_ppis():
    """Retrieve all PPIs from the database (layer 12) for comparison"""
    url = "https://gis.summitcountyco.gov/arcgis/rest/services/ParcelQueryTool/SummitMap1_Pro321/MapServer/12/query"
    
    all_features = []
    batch_size = 1000
    offset = 0
    params = {
        "where": "1=1",
        "outFields": "*",  # Get all fields for matching features
        "f": "json",
        "returnGeometry": "false",
        "outSR": "102654",
        "resultRecordCount": batch_size
    }
    
    print("Loading database PPIs for comparison...")
    
    try:
        while True:
            params["resultOffset"] = offset
            
            response = requests.get(url, params=params)
            response.raise_for_status()
            
            data = response.json()
            
            if "features" not in data or not data["features"]:
                break
                
            all_features.extend(data["features"])
            
            if len(data["features"]) < batch_size:
                break
                
            offset += batch_size
        
        # Create a dictionary mapping PPI to feature data
        ppi_to_feature = {}
        for feature in all_features:
            ppi = feature.get("attributes", {}).get("PPI")
            if ppi is not None:
                ppi_to_feature[ppi] = feature
        
        print(f"Loaded {len(ppi_to_feature)} unique PPIs from database")
        return ppi_to_feature
        
    except requests.exceptions.RequestException as e:
        print(f"Error querying the database: {e}")
        return {}

def main():
    num_results = 5
    
    # Get database PPIs for comparison
    database_ppis = get_database_ppis()
    
    if not database_ppis:
        print("Failed to load database PPIs. Exiting.")
        return
    
    # Query URL with adjustable result count
    query_url = f"https://gis.summitcountyco.gov/arcgis/rest/services/ParcelQueryTool/SummitMap1_Pro321/MapServer/19/query?where=SOURCE=1&orderByFields=MODDATE%20DESC&resultRecordCount={num_results}&outFields=*&returnGeometry=false&f=json"
    
    # Send the request
    response = requests.get(query_url)
    if response.status_code == 200:
        data = response.json()
        features = data.get("features", [])
        
        matching_count = 0
        
        for i, feature in enumerate(features, 1):
            attributes = feature.get("attributes", {})
            ppi = attributes.get("PPI")
            mod_date = attributes.get("MODDATE")
            
            # Convert MODDATE (Unix timestamp in milliseconds) to readable date
            if mod_date:
                mod_date_readable = datetime.fromtimestamp(mod_date / 1000).strftime("%Y-%m-%d %H:%M:%S")
            else:
                mod_date_readable = "N/A"
            
            # Only print if PPI exists in database
            if ppi in database_ppis:
                matching_count += 1
                database_feature = database_ppis[ppi]
                database_attributes = database_feature.get("attributes", {})
                
                if matching_count == 1:  # Print header only when first match is found
                    print(f"\nMatching PPIs from Most Recently Modified Parcels:")
                
                print(f"\n--- Match #{matching_count} - PPI: {ppi} ---")
                print(f"Modified Date: {mod_date_readable}")
                
                # Define relevant fields for each section
                modtype_fields = [
                    'AREA', 'PERIMETER', 'OBJECTID', 'PPI', 'SOURCE', 
                    'MODDATE', 'MODTYPE'
                ]
                
                schedule_fields = [
                    'OBJECTID_1', 'OBJECTID', 'PPI', 'Schedule', 'EcoCode', 'EcoDesc',
                    'NhoodCode', 'NhoodDescr', 'SubCode', 'SubName', 'SecondID', 'ShortDesc',
                    'AddressID', 'StreetID', 'SitusAdd', 'HouseNum', 'FullStreet', 'StreetName',
                    'TownCode', 'TownName', 'OwnerAdd1', 'OwnerAdd2', 'OwnerCity', 'OwnerState',
                    'PostCode', 'FullAdd', 'TotAcres', 'TotSqFt', 'YearBuilt', 'ExtWallMat',
                    'ExtWallHgt', 'HeatType', 'SquareFeet', 'SqeFtLiving', 'Unfinished',
                    'BsmtType', 'GarageType', 'NumOfCars', 'GarSqFt', 'NumOfRms', 'NumBedRms',
                    'NumLofts', 'NumKitch', 'MasterBath', 'FullBath', 'TqtrBaths', 'HalfBaths',
                    'QtrBaths', 'TotBath', 'MobHtitle', 'FloorLevel', 'ImpPos'
                ]
                
                # Print MODTYPE attributes (from layer 19)
                print("\nMODTYPE ATTRIBUTES:")
                for field in modtype_fields:
                    if field in attributes:
                        value = attributes[field]
                        if field == 'MODDATE' and value:
                            # Convert timestamp for MODDATE display
                            value = datetime.fromtimestamp(value / 1000).strftime("%Y-%m-%d %H:%M:%S")
                        print(f"  {field}: {value}")
                
                # Print Schedule ID attributes (from layer 12)
                print("\nSCHEDULE ID ATTRIBUTES:")
                for field in schedule_fields:
                    if field in database_attributes:
                        value = database_attributes[field]
                        print(f"  {field}: {value}")
                
                print("-" * 50)
        
        # Summary
        if matching_count > 0:
            print(f"\nSUMMARY:")
            print(f"Total queried parcels: {len(features)}")
            print(f"Matching PPIs found in database: {matching_count}")
            print(f"Match percentage: {(matching_count/len(features)*100):.1f}%")
        else:
            print(f"\nNo matching PPIs found in database out of {len(features)} queried parcels.")
        
    else:
        print(f"Error: Unable to fetch data. Status code: {response.status_code}")

if __name__ == "__main__":
    main()
# Out:
# Loading database PPIs for comparison...
# Loaded 21031 unique PPIs from database
#
# Matching PPIs from Most Recently Modified Parcels:
#
# --- Match #1 - PPI: 1697-3440-00-014 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   PERIMETER: 7126.66105626297
#   OBJECTID: 367
#   PPI: 1697-3440-00-014
#   SOURCE: 1
#   MODDATE: 2025-05-26 18:00:00
#   MODTYPE: 4
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 353
#   OBJECTID: 19851
#   PPI: 1697-3440-00-014
#   Schedule: 4008327
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 9000
#   SubName: METES & BOUNDS (ALL)
#   SecondID:
#   ShortDesc: TR 2-79 Sec 34 Qtr 4 Acres 82.110 AKA TR
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   OwnerAdd1: 6060 BROADWAY
#   OwnerAdd2:
#   OwnerCity: DENVER
#   OwnerState: CO
#   PostCode: 80216
#   FullAdd: 6060 BROADWAY|DENVER, CO 80216
#   TotAcres: 82.11
#   TotSqFt: 3576711
#   YearBuilt: 0
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: 0
#   SqeFtLiving: 0
#   Unfinished: 0
#   BsmtType:
#   GarageType:
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 0
#   NumBedRms: 0
#   NumLofts: 0
#   NumKitch: 0
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
# --------------------------------------------------
#
# --- Match #2 - PPI: 1951-0610-00-016 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   PERIMETER: 912.3502390552982
#   OBJECTID: 714
#   PPI: 1951-0610-00-016
#   SOURCE: 1
#   MODDATE: 2025-05-26 18:00:00
#   MODTYPE: 4
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 618
#   OBJECTID: 18316
#   PPI: 1951-0610-00-016
#   Schedule: 3000334
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 920
#   SubName: MEADOWBROOK ACRES SUB
#   SecondID: Tract A4
#   ShortDesc: TRACT A4 MEADOWBROOK ACRES SUB
#   AddressID: 48953
#   StreetID: 1057
#   SitusAdd: 2033 Meadowbrook LN (CR 1378)
#   HouseNum: 2033
#   FullStreet: Meadowbrook LN (CR 1378)
#   StreetName: Meadowbrook
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   OwnerAdd1: 110 MOSS WAY
#   OwnerAdd2:
#   OwnerCity: SILVERTHORNE
#   OwnerState: CO
#   PostCode: 80498-7534
#   FullAdd: 110 MOSS WAY|SILVERTHORNE, CO 80498-7534
#   TotAcres: 1.098
#   TotSqFt: 47828
#   YearBuilt: 1964
#   ExtWallMat: Wood Siding
#   ExtWallHgt: -1
#   HeatType: None
#   SquareFeet: 1128
#   SqeFtLiving: 1128
#   Unfinished: 0
#   BsmtType: None
#   GarageType: None
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 4
#   NumBedRms: 2
#   NumLofts: 0
#   NumKitch: 1
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos: Standalone
# --------------------------------------------------
#
# --- Match #3 - PPI: 1951-0610-00-011 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   PERIMETER: 382.93131412708334
#   OBJECTID: 728
#   PPI: 1951-0610-00-011
#   SOURCE: 1
#   MODDATE: 2025-05-26 18:00:00
#   MODTYPE: 0
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 613
#   OBJECTID: 19217
#   PPI: 1951-0610-00-011
#   Schedule: 3001794
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 9000
#   SubName: METES & BOUNDS (ALL)
#   SecondID:
#   ShortDesc: TR 4-78 Sec 06 Qtr 1 Acres 4.0000
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   OwnerAdd1: C/O ROBERT MC DOUGAL
#   OwnerAdd2: 600 JOSEPHINE ST
#   OwnerCity: DENVER
#   OwnerState: CO
#   PostCode: 80206-3723
#   FullAdd: C/O ROBERT MC DOUGAL|600 JOSEPHINE ST|DENVER, CO 80206-3723
#   TotAcres: 4.0
#   TotSqFt: 174240
#   YearBuilt: 0
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: 0
#   SqeFtLiving: 0
#   Unfinished: 0
#   BsmtType:
#   GarageType:
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 0
#   NumBedRms: 0
#   NumLofts: 0
#   NumKitch: 0
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
# --------------------------------------------------
#
# --- Match #4 - PPI: 1951-0630-00-008 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   PERIMETER: 1000.3120100867637
#   OBJECTID: 731
#   PPI: 1951-0630-00-008
#   SOURCE: 1
#   MODDATE: 2025-05-26 18:00:00
#   MODTYPE: 4
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 637
#   OBJECTID: 18266
#   PPI: 1951-0630-00-008
#   Schedule: 3000256
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 920
#   SubName: MEADOWBROOK ACRES SUB
#   SecondID: Tract J
#   ShortDesc: TRACT J MEADOWBROOK ACRES SUB
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   OwnerAdd1: C/O W D HABISH JR
#   OwnerAdd2: PO BOX 294
#   OwnerCity: WESTMINSTER
#   OwnerState: CO
#   PostCode: 80030-0294
#   FullAdd: C/O W D HABISH JR|PO BOX 294|WESTMINSTER, CO 80030-0294
#   TotAcres: 1.0
#   TotSqFt: 43560
#   YearBuilt: 0
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: 0
#   SqeFtLiving: 0
#   Unfinished: 0
#   BsmtType:
#   GarageType:
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 0
#   NumBedRms: 0
#   NumLofts: 0
#   NumKitch: 0
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
# --------------------------------------------------
#
# --- Match #5 - PPI: 2097-3540-00-078 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   PERIMETER: 697.5742225451835
#   OBJECTID: 11034
#   PPI: 2097-3540-00-078
#   SOURCE: 1
#   MODDATE: 2025-05-26 18:00:00
#   MODTYPE: 4
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 20592
#   OBJECTID: 37152
#   PPI: 2097-3540-00-078
#   Schedule: 6518943
#   EcoCode: 2
#   EcoDesc: Frisco
#   NhoodCode: 23000
#   NhoodDescr: Frisco Town
#   SubCode: 9000
#   SubName: METES & BOUNDS (ALL)
#   SecondID:
#   ShortDesc: Improvement Only TR 5-78 Sec 35 Qtr 4 Sq
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   OwnerAdd1: PO BOX 68
#   OwnerAdd2:
#   OwnerCity: BRECKENRIDGE
#   OwnerState: CO
#   PostCode: 80424-0068
#   FullAdd: PO BOX 68|BRECKENRIDGE, CO 80424-0068
#   TotAcres: 0.0
#   TotSqFt: 0
#   YearBuilt: -1
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: -1
#   SqeFtLiving: -1
#   Unfinished: -1
#   BsmtType:
#   GarageType:
#   NumOfCars: -1
#   GarSqFt: -1
#   NumOfRms: -1
#   NumBedRms: -1
#   NumLofts: -1
#   NumKitch: -1
#   MasterBath: -1
#   FullBath: -1
#   TqtrBaths: -1
#   HalfBaths: -1
#   QtrBaths: -1
#   TotBath: -1.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
# --------------------------------------------------
#
# SUMMARY:
# Total queried parcels: 5
# Matching PPIs found in database: 5
# Match percentage: 100.0%

# %% [markdown]
# # Adjusting Previous Code to Handle Data in Strictly JSON Format

# %%
import requests
from datetime import datetime

def get_database_ppis():
    """Retrieve all PPIs from the database (layer 12) for comparison"""
    url = "https://gis.summitcountyco.gov/arcgis/rest/services/ParcelQueryTool/SummitMap1_Pro321/MapServer/12/query"
    
    all_features = []
    batch_size = 1000
    offset = 0
    params = {
        "where": "1=1",
        "outFields": "*",  # Get all fields for matching features
        "f": "json",
        "returnGeometry": "false",
        "outSR": "102654",
        "resultRecordCount": batch_size
    }
    
    print("Loading database PPIs for comparison...")
    
    try:
        while True:
            params["resultOffset"] = offset
            
            response = requests.get(url, params=params)
            response.raise_for_status()
            
            data = response.json()
            
            if "features" not in data or not data["features"]:
                break
                
            all_features.extend(data["features"])
            
            if len(data["features"]) < batch_size:
                break
                
            offset += batch_size
        
        # Create a dictionary mapping PPI to feature data
        ppi_to_feature = {}
        for feature in all_features:
            ppi = feature.get("attributes", {}).get("PPI")
            if ppi is not None:
                ppi_to_feature[ppi] = feature
        
        print(f"Loaded {len(ppi_to_feature)} unique PPIs from database")
        return ppi_to_feature
        
    except requests.exceptions.RequestException as e:
        print(f"Error querying the database: {e}")
        return {}

def main():
    num_results = 5
    
    # Get database PPIs for comparison
    database_ppis = get_database_ppis()
    
    if not database_ppis:
        print("Failed to load database PPIs. Exiting.")
        return
    
    # Query URL with adjustable result count
    query_url = f"https://gis.summitcountyco.gov/arcgis/rest/services/ParcelQueryTool/SummitMap1_Pro321/MapServer/19/query?where=SOURCE=1&orderByFields=MODDATE%20DESC&resultRecordCount={num_results}&outFields=*&returnGeometry=false&f=json"
    
    # Send the request
    response = requests.get(query_url)
    if response.status_code == 200:
        data = response.json()
        features = data.get("features", [])
        
        matching_count = 0
        results_json = []  # Store results as raw JSON
        
        # Define field lists at the beginning of the loop
        modtype_fields = [
            'AREA', 'PERIMETER', 'OBJECTID', 'PPI', 'SOURCE', 
            'MODDATE', 'MODTYPE'
        ]
        
        schedule_fields = [
            'OBJECTID_1', 'OBJECTID', 'PPI', 'Schedule', 'EcoCode', 'EcoDesc',
            'NhoodCode', 'NhoodDescr', 'SubCode', 'SubName', 'SecondID', 'ShortDesc',
            'AddressID', 'StreetID', 'SitusAdd', 'HouseNum', 'FullStreet', 'StreetName',
            'TownCode', 'TownName', 'OwnerAdd1', 'OwnerAdd2', 'OwnerCity', 'OwnerState',
            'PostCode', 'FullAdd', 'TotAcres', 'TotSqFt', 'YearBuilt', 'ExtWallMat',
            'ExtWallHgt', 'HeatType', 'SquareFeet', 'SqeFtLiving', 'Unfinished',
            'BsmtType', 'GarageType', 'NumOfCars', 'GarSqFt', 'NumOfRms', 'NumBedRms',
            'NumLofts', 'NumKitch', 'MasterBath', 'FullBath', 'TqtrBaths', 'HalfBaths',
            'QtrBaths', 'TotBath', 'MobHtitle', 'FloorLevel', 'ImpPos'
        ]
        
        for i, feature in enumerate(features, 1):
            attributes = feature.get("attributes", {})
            ppi = attributes.get("PPI")
            mod_date = attributes.get("MODDATE")
            
            # Convert MODDATE (Unix timestamp in milliseconds) to readable date
            if mod_date:
                mod_date_readable = datetime.fromtimestamp(mod_date / 1000).strftime("%Y-%m-%d %H:%M:%S")
            else:
                mod_date_readable = "N/A"
            
            # Only print if PPI exists in database
            if ppi in database_ppis:
                matching_count += 1
                database_feature = database_ppis[ppi]
                database_attributes = database_feature.get("attributes", {})
                
                if matching_count == 1:  # Print header only when first match is found
                    print(f"\nMatching PPIs from Most Recently Modified Parcels:")
                
                print(f"\n--- Match #{matching_count} - PPI: {ppi} ---")
                print(f"Modified Date: {mod_date_readable}")
                
                # Collect match data for JSON storage
                match_data = {
                    'PPI': ppi,
                    'Modified Date': mod_date_readable,
                    'Raw Modified Date': mod_date,
                    'MODTYPE Attributes': {},
                    'Schedule ID Attributes': {}
                }
                
                # Collect MODTYPE attributes
                for field in modtype_fields:
                    if field in attributes:
                        match_data['MODTYPE Attributes'][field] = attributes[field]
                
                # Collect Schedule ID attributes
                for field in schedule_fields:
                    if field in database_attributes:
                        match_data['Schedule ID Attributes'][field] = database_attributes[field]
                
                # Add to results JSON
                results_json.append(match_data)
                
                # Print MODTYPE attributes (from layer 19)
                print("\nMODTYPE ATTRIBUTES:")
                for field in modtype_fields:
                    if field in attributes:
                        value = attributes[field]
                        if field == 'MODDATE' and value:
                            # Convert timestamp for MODDATE display
                            value = datetime.fromtimestamp(value / 1000).strftime("%Y-%m-%d %H:%M:%S")
                        print(f"  {field}: {value}")
                
                # Print Schedule ID attributes (from layer 12)
                print("\nSCHEDULE ID ATTRIBUTES:")
                for field in schedule_fields:
                    if field in database_attributes:
                        value = database_attributes[field]
                        print(f"  {field}: {value}")
                
                print("-" * 50)
        
        # Summary
        if matching_count > 0:
            print(f"\nSUMMARY:")
            print(f"Total queried parcels: {len(features)}")
            print(f"Matching PPIs found in database: {matching_count}")
            print(f"Match percentage: {(matching_count/len(features)*100):.1f}%")
            
            # Return the JSON results for further processing
            return results_json
        else:
            print(f"\nNo matching PPIs found in database out of {len(features)} queried parcels.")
            return []
        
    else:
        print(f"Error: Unable to fetch data. Status code: {response.status_code}")
        return []

if __name__ == "__main__":
    # Run main and capture JSON results
    json_results = main()
    
    # Optional: Print the JSON structure for verification
    if json_results:
        print(f"\n--- JSON RESULTS SAVED ---")
        print(f"Number of records stored: {len(json_results)}")
        # Uncomment the next line to see the full JSON structure:
        # import json; print(json.dumps(json_results, indent=2))
# Out:
# Loading database PPIs for comparison...
# Loaded 21031 unique PPIs from database
#
# Matching PPIs from Most Recently Modified Parcels:
#
# --- Match #1 - PPI: 1697-3440-00-014 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   PERIMETER: 7126.66105626297
#   OBJECTID: 367
#   PPI: 1697-3440-00-014
#   SOURCE: 1
#   MODDATE: 2025-05-26 18:00:00
#   MODTYPE: 4
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 353
#   OBJECTID: 19851
#   PPI: 1697-3440-00-014
#   Schedule: 4008327
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 9000
#   SubName: METES & BOUNDS (ALL)
#   SecondID:
#   ShortDesc: TR 2-79 Sec 34 Qtr 4 Acres 82.110 AKA TR
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   OwnerAdd1: 6060 BROADWAY
#   OwnerAdd2:
#   OwnerCity: DENVER
#   OwnerState: CO
#   PostCode: 80216
#   FullAdd: 6060 BROADWAY|DENVER, CO 80216
#   TotAcres: 82.11
#   TotSqFt: 3576711
#   YearBuilt: 0
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: 0
#   SqeFtLiving: 0
#   Unfinished: 0
#   BsmtType:
#   GarageType:
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 0
#   NumBedRms: 0
#   NumLofts: 0
#   NumKitch: 0
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
# --------------------------------------------------
#
# --- Match #2 - PPI: 1951-0610-00-016 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   PERIMETER: 912.3502390552982
#   OBJECTID: 714
#   PPI: 1951-0610-00-016
#   SOURCE: 1
#   MODDATE: 2025-05-26 18:00:00
#   MODTYPE: 4
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 618
#   OBJECTID: 18316
#   PPI: 1951-0610-00-016
#   Schedule: 3000334
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 920
#   SubName: MEADOWBROOK ACRES SUB
#   SecondID: Tract A4
#   ShortDesc: TRACT A4 MEADOWBROOK ACRES SUB
#   AddressID: 48953
#   StreetID: 1057
#   SitusAdd: 2033 Meadowbrook LN (CR 1378)
#   HouseNum: 2033
#   FullStreet: Meadowbrook LN (CR 1378)
#   StreetName: Meadowbrook
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   OwnerAdd1: 110 MOSS WAY
#   OwnerAdd2:
#   OwnerCity: SILVERTHORNE
#   OwnerState: CO
#   PostCode: 80498-7534
#   FullAdd: 110 MOSS WAY|SILVERTHORNE, CO 80498-7534
#   TotAcres: 1.098
#   TotSqFt: 47828
#   YearBuilt: 1964
#   ExtWallMat: Wood Siding
#   ExtWallHgt: -1
#   HeatType: None
#   SquareFeet: 1128
#   SqeFtLiving: 1128
#   Unfinished: 0
#   BsmtType: None
#   GarageType: None
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 4
#   NumBedRms: 2
#   NumLofts: 0
#   NumKitch: 1
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos: Standalone
# --------------------------------------------------
#
# --- Match #3 - PPI: 1951-0610-00-011 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   PERIMETER: 382.93131412708334
#   OBJECTID: 728
#   PPI: 1951-0610-00-011
#   SOURCE: 1
#   MODDATE: 2025-05-26 18:00:00
#   MODTYPE: 0
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 613
#   OBJECTID: 19217
#   PPI: 1951-0610-00-011
#   Schedule: 3001794
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 9000
#   SubName: METES & BOUNDS (ALL)
#   SecondID:
#   ShortDesc: TR 4-78 Sec 06 Qtr 1 Acres 4.0000
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   OwnerAdd1: C/O ROBERT MC DOUGAL
#   OwnerAdd2: 600 JOSEPHINE ST
#   OwnerCity: DENVER
#   OwnerState: CO
#   PostCode: 80206-3723
#   FullAdd: C/O ROBERT MC DOUGAL|600 JOSEPHINE ST|DENVER, CO 80206-3723
#   TotAcres: 4.0
#   TotSqFt: 174240
#   YearBuilt: 0
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: 0
#   SqeFtLiving: 0
#   Unfinished: 0
#   BsmtType:
#   GarageType:
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 0
#   NumBedRms: 0
#   NumLofts: 0
#   NumKitch: 0
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
# --------------------------------------------------
#
# --- Match #4 - PPI: 1951-0630-00-008 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   PERIMETER: 1000.3120100867637
#   OBJECTID: 731
#   PPI: 1951-0630-00-008
#   SOURCE: 1
#   MODDATE: 2025-05-26 18:00:00
#   MODTYPE: 4
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 637
#   OBJECTID: 18266
#   PPI: 1951-0630-00-008
#   Schedule: 3000256
#   EcoCode: 1
#   EcoDesc: Lower Blue Basin
#   NhoodCode: 24800
#   NhoodDescr: Lower Blue River Valley
#   SubCode: 920
#   SubName: MEADOWBROOK ACRES SUB
#   SecondID: Tract J
#   ShortDesc: TRACT J MEADOWBROOK ACRES SUB
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   OwnerAdd1: C/O W D HABISH JR
#   OwnerAdd2: PO BOX 294
#   OwnerCity: WESTMINSTER
#   OwnerState: CO
#   PostCode: 80030-0294
#   FullAdd: C/O W D HABISH JR|PO BOX 294|WESTMINSTER, CO 80030-0294
#   TotAcres: 1.0
#   TotSqFt: 43560
#   YearBuilt: 0
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: 0
#   SqeFtLiving: 0
#   Unfinished: 0
#   BsmtType:
#   GarageType:
#   NumOfCars: 0
#   GarSqFt: 0
#   NumOfRms: 0
#   NumBedRms: 0
#   NumLofts: 0
#   NumKitch: 0
#   MasterBath: 0
#   FullBath: 0
#   TqtrBaths: 0
#   HalfBaths: 0
#   QtrBaths: 0
#   TotBath: 0.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
# --------------------------------------------------
#
# --- Match #5 - PPI: 2097-3540-00-078 ---
# Modified Date: 2025-05-26 18:00:00
#
# MODTYPE ATTRIBUTES:
#   PERIMETER: 697.5742225451835
#   OBJECTID: 11034
#   PPI: 2097-3540-00-078
#   SOURCE: 1
#   MODDATE: 2025-05-26 18:00:00
#   MODTYPE: 4
#
# SCHEDULE ID ATTRIBUTES:
#   OBJECTID_1: 20592
#   OBJECTID: 37152
#   PPI: 2097-3540-00-078
#   Schedule: 6518943
#   EcoCode: 2
#   EcoDesc: Frisco
#   NhoodCode: 23000
#   NhoodDescr: Frisco Town
#   SubCode: 9000
#   SubName: METES & BOUNDS (ALL)
#   SecondID:
#   ShortDesc: Improvement Only TR 5-78 Sec 35 Qtr 4 Sq
#   AddressID: -1
#   StreetID: -1
#   SitusAdd:
#   HouseNum:
#   FullStreet:
#   StreetName:
#   TownCode: SC
#   TownName: Unincorporated Summit County
#   OwnerAdd1: PO BOX 68
#   OwnerAdd2:
#   OwnerCity: BRECKENRIDGE
#   OwnerState: CO
#   PostCode: 80424-0068
#   FullAdd: PO BOX 68|BRECKENRIDGE, CO 80424-0068
#   TotAcres: 0.0
#   TotSqFt: 0
#   YearBuilt: -1
#   ExtWallMat:
#   ExtWallHgt: -1
#   HeatType:
#   SquareFeet: -1
#   SqeFtLiving: -1
#   Unfinished: -1
#   BsmtType:
#   GarageType:
#   NumOfCars: -1
#   GarSqFt: -1
#   NumOfRms: -1
#   NumBedRms: -1
#   NumLofts: -1
#   NumKitch: -1
#   MasterBath: -1
#   FullBath: -1
#   TqtrBaths: -1
#   HalfBaths: -1
#   QtrBaths: -1
#   TotBath: -1.0
#   MobHtitle:
#   FloorLevel: 0
#   ImpPos:
# --------------------------------------------------
#
# SUMMARY:
# Total queried parcels: 5
# Matching PPIs found in database: 5
# Match percentage: 100.0%
#
# --- JSON RESULTS SAVED ---
# Number of records stored: 5

# %% [markdown]
# # Saving the Results Just in Case

# %%
if json_results:
    import json
    with open('parcel_results.json', 'w') as f:
        json.dump(json_results, f, indent=2)
    print("Results saved to parcel_results.json")
# Out:
# Results saved to parcel_results.json

# %% [markdown]
# # Parsing Through the JSON Results

# %%
# For the first matching record:
schedule_value = json_results[0]['Schedule ID Attributes']['Schedule']

# To loop through all records and access Schedule:
for record in json_results:
    schedule = record['Schedule ID Attributes']['Schedule']

# To get all Schedule values as a list:
schedules = [record['Schedule ID Attributes']['Schedule'] for record in json_results]

for id in schedules:
    scrape_url = f'https://gis.summitcountyco.gov/map/DetailData.aspx?Schno={id}'
    requests.get(scrape_url)
    print(scrape_url)
# Out:
# https://gis.summitcountyco.gov/map/DetailData.aspx?Schno=4008327
# https://gis.summitcountyco.gov/map/DetailData.aspx?Schno=3000334
# https://gis.summitcountyco.gov/map/DetailData.aspx?Schno=3001794
# https://gis.summitcountyco.gov/map/DetailData.aspx?Schno=3000256
# https://gis.summitcountyco.gov/map/DetailData.aspx?Schno=6518943
